# %%
import tensorflow as tf
from sources.GCAM import make_gradcam_heatmap, save_and_display_gradcam
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('savedmodels/brain_tumor_InceptionV3.h5')

# %%
img_path = "input\Testing\meningioma\Te-me_0110.jpg"
heatmap, pred_index = make_gradcam_heatmap(img_path, model, last_conv_layer_name='conv2d_69')
save_and_display_gradcam(img_path, heatmap, pred_index, cam_path="CAM/IV3_meninioma_false.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=420x290>
